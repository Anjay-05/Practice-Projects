# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings 
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("abalone.csv")
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
df.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %% [markdown]
# The input variable Sex is object data type. Length,Diameter,Height,Whole weight,Shucked weight,viscera weight and shell weight are of float data type. The ouput variable is integer data type.

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is no null value in the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %% [markdown]
# The dataset has 4177 rows and 9 columns.

# %% [markdown]
# Data Visualization

# %%
sns.countplot(df['Sex'])
df['Sex'].value_counts()
# Out:
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64

# %% [markdown]
# In the Sex column there are 1528-M,1342-I and 1307 F data are present.

# %%
sns.distplot(df['Length'],color='Green')
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Density'>

# %%
sns.distplot(df['Diameter'],color='Green')
# Out:
# <AxesSubplot:xlabel='Diameter', ylabel='Density'>

# %%
sns.distplot(df['Height'],color='green')
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %%
sns.distplot(df['Whole weight'],color='Green')
# Out:
# <AxesSubplot:xlabel='Whole weight', ylabel='Density'>

# %%
sns.distplot(df['Shucked weight'],color='Green')
# Out:
# <AxesSubplot:xlabel='Shucked weight', ylabel='Density'>

# %%
sns.distplot(df['Viscera weight'],color='Green')
# Out:
# <AxesSubplot:xlabel='Viscera weight', ylabel='Density'>

# %%
sns.distplot(df['Shell weight'],color='Green')
# Out:
# <AxesSubplot:xlabel='Shell weight', ylabel='Density'>

# %%
sns.distplot(df['Rings'],color='Green')
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Density'>

# %%
sns.countplot(df['Rings'])
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='count'>

# %% [markdown]
# The data distribution is left skewed in Length and Diameter. The data distribution is right skewed in Whole weight,Shucked weight,Viscera weight,Shell weight.

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %% [markdown]
# The Mean is more than median in Whole weight,Shucked weight,Viscera weight,Shell weight. So outliers are present.
#
# The standard deviation is looking good.

# %%
#Using label encoder encoding the Sex column
from sklearn.preprocessing import LabelEncoder

LE=LabelEncoder()
df['Sex']=LE.fit_transform(df['Sex'])
df
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df.skew()
# Out:
# Sex              -0.098155
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# dtype: float64

# %% [markdown]
# Skewness is present in the Height

# %%
#Removing skewness
df['Height']=np.sqrt(df['Height'])
df.skew()
# Out:
# Sex              -0.098155
# Length           -0.639873
# Diameter         -0.609198
# Height           -0.295641
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# dtype: float64

# %%
sns.regplot(df['Length'],df['Height'])
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Height'>

# %%
sns.regplot(df['Length'],df['Diameter'])
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Diameter'>

# %%
sns.regplot(df['Length'],df['Whole weight'])
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Whole weight'>

# %%
sns.regplot(df['Length'],df['Shucked weight'])
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Shucked weight'>

# %%
sns.regplot(df['Length'],df['Viscera weight'])
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Viscera weight'>

# %%
sns.regplot(df['Length'],df['Shell weight'])
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Shell weight'>

# %%
sns.regplot(df['Length'],df['Rings'])
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Rings'>

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                      Sex    Length  Diameter    Height  Whole weight  \
# Sex             1.000000 -0.036066 -0.038874 -0.040410     -0.021391
# Length         -0.036066  1.000000  0.986812  0.883322      0.925261
# Diameter       -0.038874  0.986812  1.000000  0.888117      0.925452
# Height         -0.040410  0.883322  0.888117  1.000000      0.843708
# Whole weight   -0.021391  0.925261  0.925452  0.843708      1.000000
# Shucked weight -0.001373  0.897914  0.893162  0.797910      0.969405
# Viscera weight -0.032067  0.903018  0.899724  0.822861      0.966375
# Shell weight   -0.034854  0.897706  0.905330  0.841225      0.955355
# Rings          -0.034627  0.556720  0.574660  0.592653      0.540390
#
#                 Shucked weight  Viscera weight  Shell weight     Rings
# Sex                  -0.001373       -0.032067     -0.034854 -0.034627
# Length                0.897914        0.903018      0.897706  0.556720
# ...

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The heatmap shows that Length and Diamter is highly correlated. Whole weight and shucked weight,viscera weight,shell weight is also highly correlated.
#
# The output variable/label is mostly correlated to the Shell weight and least correlated to the Shucked weight.

# %% [markdown]
# Checking Outliers

# %%
df['Length'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Height'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Diameter'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Whole weight'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Shucked weight'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Viscera weight'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Shell weight'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Rings'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Outliers are present in Whole weight,Shucked weight,Viscera weight,Shell weight

# %%
#Finding out outliers
from scipy.stats import zscore

score=np.abs(zscore(df))
print(np.where(score>3))
# Out:
# (array([   6,   72,   81,   83,  129,  163,  164,  165,  165,  165,  166,
#         166,  167,  168,  170,  181,  232,  236,  236,  236,  237,  237,
#         237,  238,  238,  238,  239,  239,  270,  275,  277,  278,  294,
#         306,  310,  313,  314,  334,  351,  355,  358,  358,  362,  375,
#         416,  417,  428,  431,  433,  469,  478,  480,  501,  526,  526,
#         530,  572,  628,  673,  674,  675,  678,  694,  694,  696,  696,
#         718,  719,  719,  719,  720,  720,  720,  744,  754,  756,  811,
#         891,  891,  891, 1048, 1051, 1051, 1052, 1174, 1193, 1197, 1199,
#        1202, 1204, 1206, 1206, 1207, 1207, 1207, 1207, 1209, 1209, 1257,
#        1417, 1417, 1418, 1422, 1426, 1427, 1427, 1427, 1428, 1429, 1429,
#        1429, 1528, 1754, 1756, 1757, 1759, 1761, 1762, 1762, 1762, 1763,
#        1763, 1763, 1821, 1982, 1986, 1987, 1987, 1987, 2051, 2090, 2108,
#        2108, 2114, 2114, 2114, 2157, 2161, 2169, 2171, 2172, 2176, 2180,
# ...

# %%
#Removing outliers
dfnew=df[(score<3).all(axis=1)]
print('dfnew.shape = ',dfnew.shape)
df=dfnew
# Out:
# dfnew.shape =  (4019, 9)

# %%
df.corr()
# Out:
#                      Sex    Length  Diameter    Height  Whole weight  \
# Sex             1.000000 -0.043978 -0.046893 -0.047602     -0.034812
# Length         -0.043978  1.000000  0.985807  0.907285      0.935022
# Diameter       -0.046893  0.985807  1.000000  0.912648      0.934606
# Height         -0.047602  0.907285  0.912648  1.000000      0.882321
# Whole weight   -0.034812  0.935022  0.934606  0.882321      1.000000
# Shucked weight -0.016429  0.909742  0.904681  0.835174      0.970881
# Viscera weight -0.045187  0.908448  0.904582  0.860207      0.966476
# Shell weight   -0.043998  0.914874  0.922138  0.889508      0.961026
# Rings          -0.033682  0.563535  0.581657  0.616311      0.545911
#
#                 Shucked weight  Viscera weight  Shell weight     Rings
# Sex                  -0.016429       -0.045187     -0.043998 -0.033682
# Length                0.909742        0.908448      0.914874  0.563535
# ...

# %%
#Checking outliers using boxplot
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1

for column in df:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        df[column].plot.box()
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
data_loss=((4177-4019)/4177)*100
data_loss
# Out:
# 3.782619104620541

# %% [markdown]
# 3.78% data loss after outliers removed.

# %%
#Separating input and output variables

X=df.drop('Rings',axis=1)
Y=df['Rings']
print(len(X))
print(len(Y))
# Out:
# 4019
# 4019

# %%
X
# Out:
#       Sex  Length  Diameter    Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365  0.308221        0.5140          0.2245
# 1       2   0.350     0.265  0.300000        0.2255          0.0995
# 2       0   0.530     0.420  0.367423        0.6770          0.2565
# 3       2   0.440     0.365  0.353553        0.5160          0.2155
# 4       1   0.330     0.255  0.282843        0.2050          0.0895
# ...   ...     ...       ...       ...           ...             ...
# 4172    0   0.565     0.450  0.406202        0.8870          0.3700
# 4173    2   0.590     0.440  0.367423        0.9660          0.4390
# 4174    2   0.600     0.475  0.452769        1.1760          0.5255
# 4175    0   0.625     0.485  0.387298        1.0945          0.5310
# 4176    2   0.710     0.555  0.441588        1.9485          0.9455
#
#       Viscera weight  Shell weight
# 0             0.1010        0.1500
# 1             0.0485        0.0700
# 2             0.1415        0.2100
# ...

# %%
Y
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4019, dtype: int64

# %%
#Checking multicollinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(X.values,i) for i in range(X.shape[1])] 
vif['Features']=X.columns
vif
# Out:
#           VIF        Features
# 0    2.632493             Sex
# 1  802.340579          Length
# 2  763.963727        Diameter
# 3  154.948351          Height
# 4  441.891678    Whole weight
# 5  110.275122  Shucked weight
# 6   65.499021  Viscera weight
# 7   92.744708    Shell weight

# %% [markdown]
# There is multicollinearity between Length vs Diameter and Height vs Shucked weight.

# %%
X=X.drop(['Length','Shucked weight'],axis=1)

# %%
X
# Out:
#       Sex  Diameter    Height  Whole weight  Viscera weight  Shell weight
# 0       2     0.365  0.308221        0.5140          0.1010        0.1500
# 1       2     0.265  0.300000        0.2255          0.0485        0.0700
# 2       0     0.420  0.367423        0.6770          0.1415        0.2100
# 3       2     0.365  0.353553        0.5160          0.1140        0.1550
# 4       1     0.255  0.282843        0.2050          0.0395        0.0550
# ...   ...       ...       ...           ...             ...           ...
# 4172    0     0.450  0.406202        0.8870          0.2390        0.2490
# 4173    2     0.440  0.367423        0.9660          0.2145        0.2605
# 4174    2     0.475  0.452769        1.1760          0.2875        0.3080
# 4175    0     0.485  0.387298        1.0945          0.2610        0.2960
# 4176    2     0.555  0.441588        1.9485          0.3765        0.4950
#
# [4019 rows x 6 columns]

# %%
#Scaling dataponits using standardscaler
from sklearn.preprocessing import StandardScaler

scale=StandardScaler()
X_scale=scale.fit_transform(X)
X_scale
# Out:
# array([[ 1.15835802, -0.42766545, -1.1645936 , -0.63693837, -0.7267137 ,
#         -0.63462928],
#        [ 1.15835802, -1.4770503 , -1.32420851, -1.27043818, -1.23554834,
#         -1.26104553],
#        [-1.28480172,  0.14949622, -0.01509984, -0.27901646, -0.33418412,
#         -0.1648171 ],
#        ...,
#        [ 1.15835802,  0.72665788,  1.64199279,  0.81670767,  1.08086078,
#          0.60254279],
#        [-1.28480172,  0.83159637,  0.37079505,  0.63774671,  0.82402043,
#          0.50858036],
#        [ 1.15835802,  1.56616576,  1.4248959 ,  2.51299401,  1.94345664,
#          2.06679076]])

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(X_scale,Y,test_size=0.30,random_state=42)

# %%
print(X.shape)
print(Y.shape)
# Out:
# (4019, 6)
# (4019,)

# %% [markdown]
# Linear regression

# %%
from sklearn.linear_model import LinearRegression,LogisticRegression

lr=LinearRegression()
lr.fit(x_train,y_train)
lr.score(x_train,y_train)
# Out:
# 0.4542161388265302

# %%
from sklearn.metrics import r2_score,accuracy_score,confusion_matrix

lrpred=lr.predict(x_test)
print(r2_score(y_test,lrpred))
# Out:
# 0.45240573463877254

# %% [markdown]
# Logistic Regression

# %%
ls=LogisticRegression()
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
# Out:
# 0.2915037326697476

# %%
lspred=ls.predict(x_test)
print(r2_score(y_test,lspred))
# Out:
# 0.29894899450872303

# %%
from sklearn.svm import SVR

svr=SVR()
svr.fit(x_train,y_train)
svr.score(x_train,y_train)
# Out:
# 0.48533887543476784

# %%
svrpred=svr.predict(x_test)
print(r2_score(y_test,svrpred))
# Out:
# 0.47192367755868214

# %% [markdown]
# Regularization

# %%
from sklearn.linear_model import Ridge,Lasso,RidgeCV,LassoCV

rdg=Ridge(alpha=.0001,random_state=45)
rdg.fit(x_train,y_train)
rdg.score(x_train,y_train)
# Out:
# 0.4542161388264496

# %%
rdgpred=rdg.predict(x_test)
r2_score(y_test,rdgpred)
# Out:
# 0.452405724248781

# %%
lso=Lasso(alpha=.0001,random_state=47)
lso.fit(x_train,y_train)
lso.score(x_train,y_train)
# Out:
# 0.45421595952762206

# %%
lsopred=lso.predict(x_test)
r2_score(y_test,lsopred)
# Out:
# 0.4524037874236898

# %% [markdown]
# Cross validation

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(lr,X,Y,cv=10)
print(score)
print(score.mean())
print(score.std())
# Out:
# [ 0.45917792  0.1983074   0.28287952 -0.04797207  0.25270633  0.3855647
#   0.36702403  0.35606547  0.3938583   0.41094009]
# 0.30585516871258667
# 0.13965116786524623

# %%
score=cross_val_score(ls,X,Y,cv=10)
print(score)
print(score.mean())
print(score.std())
# Out:
# [0.20149254 0.23880597 0.2761194  0.30597015 0.28109453 0.23631841
#  0.27363184 0.26119403 0.26865672 0.29177057]
# 0.2635054155655637
# 0.028982543443102603

# %%
score=cross_val_score(svr,X,Y,cv=10)
print(score)
print(score.mean())
print(score.std())
# Out:
# [0.28338865 0.04960906 0.48559768 0.45305495 0.52711754 0.19339241
#  0.58002983 0.24143353 0.49354206 0.42646749]
# 0.3733633185073565
# 0.16287079584124833

# %%
score=cross_val_score(rdg,X,Y,cv=10)
print(score)
print(score.mean())
print(score.std())
# Out:
# [ 0.45917734  0.19830411  0.28287705 -0.04795969  0.25271372  0.38556081
#   0.36702394  0.35606667  0.39385828  0.41094033]
# 0.30585625495658414
# 0.13964781341463023

# %%
score=cross_val_score(lso,X,Y,cv=10)
print(score)
print(score.mean())
print(score.std())
# Out:
# [ 0.45902419  0.19778525  0.28256058 -0.04480061  0.25366789  0.38492932
#   0.36756129  0.35606826  0.39427607  0.41113031]
# 0.30622025432237454
# 0.13886935572747647

# %% [markdown]
# Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
grid_para={'kernel':('poly','rbf','linear'),'C':[1,10,100]}

# %%
grid_search=GridSearchCV(estimator=svr,param_grid=grid_para,cv=10)
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=SVR(),
#              param_grid={'C': [1, 10, 100],
#                          'kernel': ('poly', 'rbf', 'linear')})

# %%
best_para=grid_search.best_params_
print(best_para)
# Out:
# {'C': 10, 'kernel': 'rbf'}

# %%
svr=SVR(kernel='rbf',C=10)
svr.fit(x_train,y_train)
pred_svr=svr.predict(x_test)
print(r2_score(y_test,pred_svr))
# Out:
# 0.4851789578894605

# %% [markdown]
# The model r2 score and crossvalidation score is 48.5%

# %%
import pickle
filename="Abalone Case.pkl"
pickle.dump(svr,open(filename, 'wb'))

# %% [markdown]
# Conclusion

# %%
model=pickle.load(open("Abalone Case.pkl",'rb'))
result=model.score(x_test,y_test)
print(result)
# Out:
# 0.4851789578894605

# %%
Accuracy=pd.DataFrame([model.predict(x_test),pred_svr],index=['Predicted','Original'])
Accuracy
# Out:
#                0         1          2         3         4          5     \
# Predicted  8.545192  7.407384  11.515582  6.852023  8.556925  14.263691
# Original   8.545192  7.407384  11.515582  6.852023  8.556925  14.263691
#
#                6         7         8         9     ...       1196      1197  \
# Predicted  5.606746  9.896423  4.863838  8.346052  ...  13.626368  8.159754
# Original   5.606746  9.896423  4.863838  8.346052  ...  13.626368  8.159754
#
#                1198      1199      1200      1201      1202      1203  \
# Predicted  9.838637  9.540316  9.698927  8.812982  8.846525  9.703691
# Original   9.838637  9.540316  9.698927  8.812982  8.846525  9.703691
#
#                1204      1205
# Predicted  7.048814  9.060007
# Original   7.048814  9.060007
#
# [2 rows x 1206 columns]
